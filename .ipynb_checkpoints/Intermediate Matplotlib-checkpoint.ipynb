# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

% %matplotlib inline

# %%
s = pd.Series(np.array([1,2,3,4,5,6,7,6,3,5,2,7,1]))
y = s*2
plt.plot(s)
plt.scatter(s, y)

# %%
fig = plt.figure()
ax = fig.add_subplot()

# %%
# Create some random data.
import random
x = [random.randrange(10) for n in range(10)]
y = [random.randrange(10) for n in range(10)]
z = [random.randrange(10) for n in range(10)]

# Create plots.
fig, ([ax_topL, ax_topM, ax_topR], [ax_botL, ax_botM, ax_botR]) = plt.subplots(nrows=2, ncols=3, figsize=(8,5))

# Plot data.
ax_topM.scatter(x, y)
ax_botR.plot(x, 'm*')

# %%
fig.savefig('testfig.jpeg') # save figure to file.

# %% [markdown]
# ## Formatting Plots (title, ticks, etc.)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, facecolor='skyblue', linewidth=10, edgecolor='green')

# %% [markdown]
# ## Borders
#
# The borders around a Matplotlib chart are called **spines**, and they are attributes of the ax object. There are four (top, right, bottom, and left), and they can all be turned on or off, as well as customized.
# #### ax.spines[whichspine].attribute(value)

# %%
fig, ax = plt.subplots()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_linestyle('dashdot')
ax.spines['bottom'].set_color('blue')
ax.spines['left'].set_linewidth(5)
ax.tick_params(axis='x', which='major', color='blue', length=5, width=2)

# %%
fig, ax = plt.subplots()

ax.tick_params(labelleft=True)
ax.minorticks_on()
ax.set_yticks([1,2,3,4,5])
ax.set_xlim(0,3)
ax.tick_params(right=True, labelright=True) # Turn off the right ticks but KEEP their labels.

# %%
fig, ax = plt.subplots()
ax.set_title('Title Here')
ax.set_xlabel('X Axis Name')
ax.set_ylabel('Y Axis Name')
# Out:
# Text(0,0.5,'Y Axis Name')

# %%
fig, ax = plt.subplots()
colors = ['red','orange','yellow','green','blue','purple','magenta']

ax.set_xticks(range(len(colors))) # Arrange the ticks along the x axis.
ax.set_title('Mel Title Here', fontname='impact')
ax.set_xticklabels(colors, rotation=45) # Add labels to the ticks.
ax.tick_params(axis='x', labelcolor='magenta', labelsize=10) # Change the color and font size of the labels.

# %%
fig, ax = plt.subplots()
ax.set_facecolor('turquoise') # If this doesn't work, try ax.set_facecolor(color).
ax.grid(True, color='white', linestyle='-', linewidth=2)

# %% [markdown]
# # Legends
# When plotting multiple sets of data on the same chart, you'll usually want to include a guide of what is what. Including a legend makes your visualizations easier to understand and interpret. There are a few steps to including this element:
#
# 1.  Include a **label parameter** for each plot when you create it (e.g., ax.scatter(x, y, label='name')).  An alternative is to *define each plot as a variable* (e.g., s1 = ax.scatter(x, y)) and then pass a tuple of variables and a tuple of labels to your legend method (ax.legend((s1, s2), ('label1', 'label2'))).
#
# 2.  After you've made your plots, include ax.legend() to create the legend on your chart. This is highly customizable, but a few key tools include:
#
# **loc**: This can be a string (like 'upper right' or 'center left') or an integer for exact coordinate placement (**bbox_to_anchor** is another way to choose placement).
# **ncol**: The number of columns.
# **prop**: Sets font properties (fontsize also exists; does not include color).
# **title**: Adds a title.
#
# 3. Make customizations to the legend background using the **.get_frame()** method and its submethods, the most useful of which is **.set_facecolor()**.

# %%
fig, ax = plt.subplots()
ax.scatter(x, y, color='pink', label='pink')
ax.scatter(x, z, color='teal', label='teal')

legend = ax.legend(loc='upper left', prop={'size':8, 'style':'italic'}, title='Guide: ')
legend.get_frame().set_facecolor('lightgrey')

# %% [markdown]
# # Annotations (skipped the explanation?)

# %% [markdown]
# ### Connecting to Pandas and Seaborn
# In the last lesson, we learned that Seaborn allows for style customization. But you can also pass customized axes objects into Seaborn to give it a jump start. Additionally, you can pass them into a Pandas plot to customize those graphs as well.
#
# Seaborn: As long as you are creating a single Seaborn plot object, you can include an ax parameter and bring in your Pyplot axes object: ** `sns.regplot(x, y, ax=ax)` ** (This will not work for pair plots or other Seaborn objects that create several axes at once).
#
# Pandas: This works in Pandas as well. Just add the ax keyword to your plotting function (e.g., ** `df.plot(ax=ax) or df.plot.bar(ax=ax)` ** ) to place your plot on your customized axes object.
#
# The key with both of these is that you must have an actual axes object. If you just used plt.plot() and haven't figured out the name of the axes object you created, you will not be able to share it with these other libraries.

# %%
fig, ax = plt.subplots(figsize=(8, 4), edgecolor='lightgrey', linewidth=3)

# %%
#df = pd.DataFrame(data=np.ndarray()random.uniform(0,9))
#df = pd.DataFrame(np.random.randint(0,100,size=(20, 4)), columns=list('ABCD'))

fig, ax = plt.subplots()
df = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=['A','B','stocks','releases'])

# Find number of data points to fit on each axis.
n_x = len(df)
n_y = max(df.releases)

#X-Axis
ax.set_xlim(0, n_x) # Increase the width of x axis to fit all of our data points.
ax.set_xticks(range(n_x + 1)) # Set tick marks as evenly spaced for the correct number of days.
ax.tick_params(axis='x', top=False) # Turn off the top ticks for a cleaner view,

#Y-Axis
ax.set_ylim(0, n_y+1) # Increase height of y axis to fit all values.

# Now add axis, title, and tick customizations:
#X-Axis
#days = [(str(d.month) + '/' + str(d.day)) for d in df.index] # Format the strings we want as the x axis labels.
all_days = ['Mon','Tues','Wed','Thurs','Fri','Sat','Sun']
#days = [all_days[x] in all_days for x in range(100)]
days = []
for x in range(df.shape[0]):
    #days = days.append(random.choice(all_days))
    #print(random.choice(all_days))
    days.append(random.choice(all_days))
#print(days)

ax.set_xticklabels(days, rotation=45, size=9, fontname='Times New Roman') # Feed our labels into the graph and format them.
ax.set_xlabel('Date', size=12, fontname='Times New Roman') # Set a label for the axis as a whole.

#Y-Axis
ax.set_ylabel('Value', size=12, fontname='Times New Roman') # Label the y axis.
for tick in ax.get_yticklabels(): # Because we don't want to reset the labels entirely, we'll add formatting to each one.
    tick.set_fontname('Times New Roman')
    tick.set_fontsize(9)

#Chart
ax.set_title('Fictional Co. January Performance', size=14, fontname='Times New Roman')

# And make a light gray background with a subtle grid:
ax.grid(True, color='darkgrey') # Add a grid with dark gray lines.
ax.set_facecolor('lightgrey') # Set the plot background to light gray.

# And plot our data (need a df defined)
ax.bar(range(n_x), df.releases, color='white', edgecolor='lightgrey', label='Press Releases')
ax.plot(df.stocks.values, color='darkgreen', label='Closing Stock Price')

'''Plotting Walk Through: Add a Legend
The only thing that's missing now is a quick visual guide to the data in the form of a legend. 
Because you added label keywords while plotting, you can simply add it by running ax.legend(). 
At this time, you can add parameters to customize the legend, too.
'''
ax.legend(loc='upper right', prop={'size':8, 'style':'italic'})

# %%
# search for screencast_unit5_lesson4
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=2, facecolor='skyblue', figsize=(15,10), linewidth=10,edgecolor='lightblue')

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/data/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
z = zip(df.columns[:-1], [ax1[0],ax1[1],ax2[0],ax2[1]])
print( x for x in z )

z2 = list(zip(df.columns[:-1], [ax1[0],ax1[1],ax2[0],ax2[1]]))
z2
# Out:
# <generator object <genexpr> at 0x11ae88d58>
# [('SepalLength', <matplotlib.axes._subplots.AxesSubplot at 0x11aea51d0>),
#  ('SepalWidth', <matplotlib.axes._subplots.AxesSubplot at 0x11aed97f0>),
#  ('PetalLength', <matplotlib.axes._subplots.AxesSubplot at 0x11aeb0748>),
#  ('PetalWidth', <matplotlib.axes._subplots.AxesSubplot at 0x11ae9a588>)]

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=2, facecolor='skyblue', figsize=(15,10))
#

for feature, ax in list(zip(df.columns[:-1], [ax1[0],ax1[1]],ax2[0],ax2[1])):
    print('here!')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-d166aec73fb6> in <module>()
#       2 #
#       3
# ----> 4 for feature, ax in list(zip(df.columns[:-1], [ax1[0],ax1[1]],ax2[0],ax2[1])[0:1]):
#       5     print('here!')
#
# TypeError: zip argument #3 must support iteration
