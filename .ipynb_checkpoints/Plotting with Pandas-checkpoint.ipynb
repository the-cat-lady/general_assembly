# %% [markdown]
# # Note - examples provided at https://git.generalassemb.ly/ariana/python-unit-5-exercises.git.  currently saved in ~/work/ds5k/general_assembly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline

# %%
df = pd.read_excel('animals.xlsx')
df
# Out:
#      animal  height kills_me vegetarian  weight
# 0  girraffe      20       no        yes    2600
# 1  elephant      14      yes        yes   12000
# 2       fox       2       no         no      25
# 3       cat       1       no         no      15
# 4      bear       8      yes         no     700
# 5    racoon       1       no         no      20

# %%
# default plot type is a line graph
df.plot(x='height', y='weight')
df.plot()

# %%
# kind keyword
df.plot.scatter(x='height', y='weight', s=300, c='orange')

# %%
df.plot.barh(x='weight', grid=True, color='gold')
df
# Out:
#      animal  height kills_me vegetarian  weight
# 0  girraffe      20       no        yes    2600
# 1  elephant      14      yes        yes   12000
# 2       fox       2       no         no      25
# 3       cat       1       no         no      15
# 4      bear       8      yes         no     700
# 5    racoon       1       no         no      20

# %%
#df['w_h_ratio'] = df.apply(np.divide(df.weight, df['height']))
#div, rem = divmod(s, 3)
rat, rem = divmod(df.weight, df.height)
df['w_h_ratio'] = rat
df
#df.reset_index(df.animal, inplace=True)
#df.set_index(df.animal, drop=True, inplace=True)
df
#df.index=df.animal
#df.reindex(index=df.animal)
# Out:
#      animal  height kills_me vegetarian  weight  w_h_ratio
# 0  girraffe      20       no        yes    2600        130
# 1  elephant      14      yes        yes   12000        857
# 2       fox       2       no         no      25         12
# 3       cat       1       no         no      15         15
# 4      bear       8      yes         no     700         87
# 5    racoon       1       no         no      20         20

# %%
df.set_index('animal', inplace=True)
#df.plot.barh(y=df.animal)

# %%
df
df.plot.barh(stacked='True')
#df.plot()

# %%
#df.plot.pie(subplots='True')
df.w_h_ratio.plot.pie()
df
# Out:
#           height kills_me vegetarian  weight  w_h_ratio
# animal
# girraffe      20       no        yes    2600        130
# elephant      14      yes        yes   12000        857
# fox            2       no         no      25         12
# cat            1       no         no      15         15
# bear           8      yes         no     700         87
# racoon         1       no         no      20         20

# %%
df.plot.scatter(x='w_h_ratio', y='height', s=200, c='w_h_ratio') #s is size, can also use c='columnname' for color scale.

# %%
df.plot.hist(stacked='True', alpha=.8) #alpha is transparency; note stacking reveals more data

# %%
df.plot.hist() # note not stacking means the blue and orange are obscured by the green in the first column.

# %%
df.hist(stacked='True')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118b1f128>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119171e80>]], dtype=object)

# %%
df.plot( alpha=.5)

# %% [markdown]
# ## EDA
# 1. inspect head() and tail() to get a feel for the data
# 1. check for nulls, and decide what to do with them.  drop? fill?  with what?
# 1. check the column datatypes with dtypes() and adjust as needed
# 1. remove any unwanted fields, and ensure the rest of them are named clearly
# 1. get summary data statistics with describe()
#
# Once this is done, try visualizing some of the data to start exploring for insights.

# %%
df.boxplot() # learn seaborn for better boxplots, but these are okay enough for now.

# %%
data = np.random.uniform(low=0.0, high=1.0, size=(20,2))
df2 = pd.DataFrame(data, columns=['A','B'])
df2
df2.plot.scatter(x='A', y='B')

# %%
df2['C'] = df2['B']*4* np.random.rand()
df2
df2.plot.scatter(x='B', y='C', s=30, c='B')

# %%
# Cool example of sorting, taking the largest 6 items, and plotting them:
df2.sort_values(by='B', ascending=False).head(6).plot.barh(y='B', x='C')

# %%
df2.B.plot.hist(bins=5)

# %%
'''
another example from video; I dont have data to go with it

df['title_length'] = df['Position Title'].map(lambda : len(x.split()))
df.plot.scatter(x='title_length',y='salary')
'''

df3 = pd.read_clipboard()
df3
df3['title_length'] = df3['title'].map(lambda x : len(x.split()))
df3.plot.scatter(x='title_length',y='salary')
df3
# Out:
#                                       title  salary  title_length
# 0  director of the bosses of the big people  182000             8
# 1                  secretary of horseradish   51000             3
# 2                  president of the company  160000             4

# %%
#df3.boxplot(column='salary', by='title_length')
df3.boxplot()
